# %%
from imports import *
# Out:
# 2024-06-19 19:08:38.512795: I tensorflow/core/util/port.cc:111] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2024-06-19 19:08:38.536039: E tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:9342] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-06-19 19:08:38.536060: E tensorflow/compiler/xla/stream_executor/cuda/cuda_fft.cc:609] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-06-19 19:08:38.536078: E tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:1518] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-06-19 19:08:38.541027: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-06-19 19:08:39.034106: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
data = pd.read_csv('data/15min1h4h/EURUSD15.csv', sep='\t')
data = data[(int(data.shape[0]/2)):]
data.columns = ['time', 'open', 'high', 'low', 'close', 'volume']
#original_data = data.copy()

# %%
pip_factor = 10000

# %%
sys.path.append('src')
from process_data import DataProcessor
from vanilla_transformer import Transformer
from visualize_data import Visualizer
from train_model import ModelTrainer
model_trainer = ModelTrainer()
data_processor = DataProcessor()
visualizer = Visualizer()

# %%
def apply_butterworth(data, order, cutoff_freq):
    sampling_rate = 1  # one every one minute
    nyquist_freq = 0.5 * sampling_rate
    normalized_cutoff_freq = cutoff_freq / nyquist_freq
    b, a = butter(order, normalized_cutoff_freq, btype='low', analog=False)
    y = filtfilt(b, a, data)
    return y

# %%
def create_four_predictions(target_idx, model, input_seq, idx0, idx1, idx2, idx3):
    pred0 = model(input_seq[idx0:idx0+1, :, :], training=False)
    pred1 = model(input_seq[idx1:idx1+1, :, :], training=False)
    pred2 = model(input_seq[idx2:idx2+1, :, :], training=False)
    pred3 = model(input_seq[idx3:idx3+1, :, :], training=False)
    return pred0, pred1, pred2, pred3

# %%
input_seq_len = 64
output_seq_len = 16

train_pct = 0.6
val_pct = 0.2

# %%
data['bw_open'] = apply_butterworth(data['open'], 5, 1/16)  # 8 minutes
data['bw_high'] = apply_butterworth(data['high'], 5, 1/16)  # 8 minutes
data['bw_low'] = apply_butterworth(data['low'], 5, 1/16)  # 8 minutes
data['bw_close'] = apply_butterworth(data['close'], 5, 1/16)  # 8 minutes

# %%
#data['rsi_close_7'] = abstract.RSI(data, timeperiod=7, price='bw_close')
data['rsi_close_14'] = abstract.RSI(data, timeperiod=7, price='bw_close')
#data['willr_close_12'] = abstract.WILLR(data, timeperiod=12, price='bw_close')
data['willr_close_42'] = abstract.WILLR(data, timeperiod=42, price='bw_close')

# %%
data.dropna(how='any', axis=0, inplace=True)

# %%
#data, _ = data_processor.normalize_custom(data, train_pct, ['volume', 'rsi_close_14', 'willr_close_42', 'bw_open', 'bw_high', 'bw_low', 'bw_close'])
data, _ = data_processor.normalize_custom(data, train_pct, ['volume', 'rsi_close_14', 'willr_close_42'])
#data, _ = data_processor.normalize_custom(data, train_pct, ['volume', 'willr_close_42', 'bw_close'])

# %%
target_time = data[['time', 'rsi_close_14', 'close']]

# %%
target = data[['close', 'rsi_close_14']]

# %%
#data.drop(['open', 'high', 'low', 'close'], axis=1, inplace=True)
data.drop(['open', 'high', 'low'], axis=1, inplace=True)

# %%
Xdata, ydata = model_trainer.create_Xy_data(data, target, input_seq_len, output_seq_len)

# %%
Xtrain_time, ytrain_c, Xval_time, yval_c, Xtest_time, ytest_c = model_trainer.split_data(Xdata, ydata, train_pct, val_pct)

# %%
Xtrain = (Xtrain_time[:, :, 2:]).astype(np.float64)
Xval = (Xval_time[:, :, 2:]).astype(np.float64)
Xtest = (Xtest_time[:, :, 2:]).astype(np.float64)

ytrain = ytrain_c[:, :, 1:]
yval = yval_c[:, :, 1:]
ytest = ytest_c[:, :, 1:]

# %%
config = {
    'input_seq_len': input_seq_len,
    'output_seq_len': output_seq_len,
    'multihead_attn_heads': 4,
    'd_k': 32,
    'd_v': 32,
    'd_ff': 32,
    'd_out': ytrain.shape[-1],
    'd_model': 32,
    'encoder_layers': 1,
    'decoder_layers': 1,
    'dropout_rate': 0.1,
    'activation': 'relu',
    'batch_size': 32,
}

# %%
epochs = 15
path = 'saved_models/tf-1806-15m.h5'

model = model_trainer.load_model_transformer(path, Xtest, config)

#model = Transformer(config)
# Out:
# 2024-06-19 19:08:46.869735: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:894] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-06-19 19:08:46.874568: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:894] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-06-19 19:08:46.874679: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:894] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-06-19 19:08:46.876335: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:894] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-06-19 19:08:46.876458: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:894] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-06-19 19:08:46.876540: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:894] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-06-19 19:08:47.120477: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:894] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-06-19 19:08:47.120606: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:894] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-06-19 19:08:47.120704: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:894] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-06-19 19:08:47.120762: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1886] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 9262 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 3060, pci bus id: 0000:01:00.0, compute capability: 8.6

# %%
model, best_epoch, train_losses, val_losses = model_trainer.train_model_transformer(Xtrain, ytrain, Xval, yval, path, epochs, model, 1e-3, config, Xtest)
# Out:
# <class 'numpy.ndarray'> <class 'numpy.ndarray'> <class 'numpy.ndarray'> <class 'numpy.ndarray'> <class 'str'> <class 'int'> <class 'vanilla_transformer.Transformer'> <class 'float'> <class 'dict'> <class 'numpy.ndarray'>
# 2024-06-18 11:17:14.530413: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x563ac4299f50 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2024-06-18 11:17:14.530430: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): NVIDIA GeForce RTX 3060, Compute Capability 8.6
# 2024-06-18 11:17:14.533336: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:269] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# 2024-06-18 11:17:14.564284: I tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:442] Loaded cuDNN version 8904
# 2024-06-18 11:17:14.618555: I ./tensorflow/compiler/jit/device_compiler.h:186] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# Epoch: 0, Loss: 0.07754689651821021, Val Loss: 0.276022704747355, Val loss improved
# Epoch: 1, Loss: 0.018912931125038075, Val Loss: 0.3257941055826139
# Epoch: 2, Loss: 0.015430283716959148, Val Loss: 0.18804669080915212, Val loss improved
# Epoch: 3, Loss: 0.00800193539939512, Val Loss: 0.18803233188660565, Val loss improved
# Epoch: 4, Loss: 0.006422363632259492, Val Loss: 0.18394271558953318, Val loss improved
# Epoch: 5, Loss: 0.005425668702333946, Val Loss: 0.18464088710408869
# Epoch: 6, Loss: 0.004618491572694367, Val Loss: 0.16929389580921442, Val loss improved
# Epoch: 7, Loss: 0.003827443778311339, Val Loss: 0.12749569255868576, Val loss improved
# Epoch: 8, Loss: 0.0033364804632012215, Val Loss: 0.12368406630272566, Val loss improved
# Epoch: 9, Loss: 0.0029548845698714045, Val Loss: 0.12579997060612944
# Epoch: 10, Loss: 0.002615735704758901, Val Loss: 0.13863463507308316
# Epoch: 11, Loss: 0.002378434379399062, Val Loss: 0.13397523940876369
# Epoch: 12, Loss: 0.00227056188998922, Val Loss: 0.124794247474451
# Epoch: 13, Loss: 0.002078529200286557, Val Loss: 0.1474797868132988
# Epoch: 14, Loss: 0.0019696403093184306, Val Loss: 0.15366327262515816
# Model with the best validation loss at epoch 8 is reloaded

# %%
pred = model(Xtest, target=None, training=False)

# %%
close_idx = 1
last_closes_input_seqs = list(Xtest_time[:, -1, close_idx])
close_idx = 0
real_closes_target_seqs = list(ytest_c[:, -1, close_idx])

# %%
real_price_movement = [a-b for a, b in zip(last_closes_input_seqs, real_closes_target_seqs)]
real_classes = data_processor.create_binary_classification_classes(real_price_movement, 0.0)

# %%
pred_mean = tf.squeeze(pred, axis=-1)
pred_mean = tf.reduce_mean(pred_mean, axis=1)
pred_mean = pred_mean.numpy().tolist()

# %%
pred_classes = data_processor.create_binary_classification_classes(pred_mean, 0.5)

# %%
visualizer.pie_number_of_price_movements_binary(real_classes, pred_classes)

# %%
accuracy_0, precision_0, recall_0, f1_0 = data_processor.create_metrics_from_classes_binary(real_classes, pred_classes)
visualizer.create_metrics_df(accuracy_0, precision_0, recall_0, f1_0)
# Out:
#       Metric     Value
# 0   Accuracy  0.450581
# 1  Precision  0.431242
# 2     Recall  0.475000
# 3   F1 Score  0.452064

# %%
ytest_mean = tf.squeeze(ytest, axis=-1)
ytest_mean = tf.reduce_mean(ytest_mean, axis=1)
ytest_mean = ytest_mean.numpy().tolist()

# %%
visualizer.plot_two_histograms(ytest_mean, pred_mean)

# %%
threshold = 0.1
pred_ternary_classes = data_processor.create_ternary_classification_classes(pred_mean, threshold, 0.5)

# %%
real_rsis_reduced, pred_rsis_reduced = data_processor.discard_little_price_movements(pred_ternary_classes, real_price_movement, pred_mean)

# %%
real_tmp = data_processor.create_binary_classification_classes(real_rsis_reduced, 0.0)
pred_tmp = data_processor.create_binary_classification_classes(pred_rsis_reduced, 0.5)

# %%
visualizer.pie_number_of_price_movements_binary(real_tmp, pred_tmp)

# %%
accuracy, precision, recall, f1 = data_processor.create_metrics_from_classes_binary(real_tmp, pred_tmp)
visualizer.create_metrics_df(accuracy, precision, recall, f1)
# Out:
#       Metric     Value
# 0   Accuracy  0.453884
# 1  Precision  0.432116
# 2     Recall  0.474441
# 3   F1 Score  0.452291

# %%
# accuracies_ternary = []
# precisions_ternary = []
# recalls_ternary = []
# f1s_ternary = []

accuracies_binary = []
precisions_binary = []
recalls_binary = []
f1s_binary = []

start = 0.0
end = 0.5
thresholds = np.linspace(start, end, 50)

for threshold in thresholds:  # threshold == 1 means one percent change in price
    #real_ternary_classes = data_processor.create_ternary_classification_classes(ytest_tmp, threshold, 0.5)
    pred_ternary_classes = data_processor.create_ternary_classification_classes(pred_mean, threshold, 0.5)
    #accuracy, precision, recall, f1 = data_processor.create_metrics_from_classes_ternary(real_ternary_classes, pred_ternary_classes)
    #accuracies_ternary.append(accuracy)
    #precisions_ternary.append(precision)
    #recalls_ternary.append(recall)
    #f1s_ternary.append(f1)

    real_rsis_reduced, pred_rsis_reduced = data_processor.discard_little_price_movements(pred_ternary_classes, real_price_movement, pred_mean)
    real_tmp = data_processor.create_binary_classification_classes(real_rsis_reduced, 0.0)
    pred_tmp = data_processor.create_binary_classification_classes(pred_rsis_reduced, 0.5)
    accuracy, precision, recall, f1 = data_processor.create_metrics_from_classes_binary(real_tmp, pred_tmp)
    accuracies_binary.append(accuracy)
    precisions_binary.append(precision)
    recalls_binary.append(recall)
    f1s_binary.append(f1)
# Out:
# /home/radekp/.local/lib/python3.11/site-packages/numpy/lib/function_base.py:518: RuntimeWarning: Mean of empty slice.
#   avg = a.mean(axis, **keepdims_kw)
# /home/radekp/.local/lib/python3.11/site-packages/numpy/core/_methods.py:192: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# /usr/lib/python3.11/site-packages/sklearn/metrics/_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/lib/python3.11/site-packages/sklearn/metrics/_classification.py:1509: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 due to no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/lib/python3.11/site-packages/sklearn/metrics/_classification.py:1509: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /home/radekp/.local/lib/python3.11/site-packages/numpy/lib/function_base.py:518: RuntimeWarning: Mean of empty slice.
#   avg = a.mean(axis, **keepdims_kw)
# /home/radekp/.local/lib/python3.11/site-packages/numpy/core/_methods.py:192: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# /usr/lib/python3.11/site-packages/sklearn/metrics/_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/lib/python3.11/site-packages/sklearn/metrics/_classification.py:1509: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 due to no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/lib/python3.11/site-packages/sklearn/metrics/_classification.py:1509: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))

# %%
visualizer.plot_metrics_binary(thresholds, accuracies_binary, precisions_binary, recalls_binary, f1s_binary, accuracy_0, precision_0, recall_0, f1_0)
